# %% [markdown]
# ## Here initial data filtration is carried out
# Removed unncessary columns form raw data file to reduce the size of each file

# %%
import pandas as pd
from pathlib import Path

# --- CONFIG ---
CHUNK_SIZE = 300_000
DROP_COLS = [
    'Data source type',
    'A','B','C','D',
    'Type of position fixing device',
    'Type of mobile',
    'Cargo type'
]
KEEP_SHIP_TYPES = {'Cargo', 'Tanker', 'Undefined'}
UNKNOWN_REPLACEMENT = '.'

# --- PATHS ---
input_folder  = Path(r"D:\Thesis Work MLS\Denmark AIS data")
output_folder = input_folder / 'processed_files'
output_folder.mkdir(exist_ok=True)

# --- SUMMARY STORAGE ---
summary = []

# --- PROCESS ---
csv_files = sorted(input_folder.glob("*.csv"))
total_files = len(csv_files)
print(f"Found {total_files} CSV files in {input_folder}")

for idx, csv_path in enumerate(csv_files, 1):
    print(f"[{idx}/{total_files}] Starting ▶ {csv_path.name}")
    orig_rows = 0
    kept_rows = 0
    first_chunk = True
    out_file = output_folder / csv_path.name

    for chunk in pd.read_csv(csv_path, chunksize=CHUNK_SIZE):
        orig_rows += len(chunk)

        # drop unwanted cols (ignore missing)
        chunk = chunk.drop(columns=DROP_COLS, errors='ignore')
        # filter longitude
        chunk = chunk[chunk['Longitude'] != 0]
        # filter ship type
        chunk = chunk[chunk['Ship type'].isin(KEEP_SHIP_TYPES)]
        # replace Unknown
        chunk = chunk.replace('Unknown', UNKNOWN_REPLACEMENT)

        kept_rows += len(chunk)

        # write out
        if first_chunk:
            chunk.to_csv(out_file, index=False, mode='w')
            first_chunk = False
        else:
            chunk.to_csv(out_file, index=False, header=False, mode='a')

    summary.append({
        'file': csv_path.name,
        'initial_rows': orig_rows,
        'processed_rows': kept_rows
    })
    print(f"[{idx}/{total_files}] Finished ✓ kept {kept_rows}/{orig_rows} rows\n")

# write summary
summary_df = pd.DataFrame(summary)
summary_df.to_csv(output_folder / 'summary.csv', index=False)
print("All done!  Summary written to", (output_folder / 'summary.csv'))
# Out:
# Found 110 CSV files in D:\Thesis Work MLS\Denmark AIS data
# [1/110] Starting ▶ aisdk-2025-01-01.csv
# [1/110] Finished ✓ kept 5972735/14166456 rows
#
# [2/110] Starting ▶ aisdk-2025-01-02.csv
# [2/110] Finished ✓ kept 5654470/14517030 rows
#
# [3/110] Starting ▶ aisdk-2025-01-03.csv
# [3/110] Finished ✓ kept 6204511/15264341 rows
#
# [4/110] Starting ▶ aisdk-2025-01-04.csv
# [4/110] Finished ✓ kept 6558978/15820358 rows
#
# [5/110] Starting ▶ aisdk-2025-01-05.csv
# [5/110] Finished ✓ kept 6651933/15945213 rows
#
# [6/110] Starting ▶ aisdk-2025-01-06.csv
# [6/110] Finished ✓ kept 6236250/15081905 rows
#
# [7/110] Starting ▶ aisdk-2025-01-07.csv
# [7/110] Finished ✓ kept 6338535/14813237 rows
#
# [8/110] Starting ▶ aisdk-2025-01-08.csv
# [8/110] Finished ✓ kept 6434965/15121354 rows
#
# [9/110] Starting ▶ aisdk-2025-01-09.csv
# [9/110] Finished ✓ kept 6539890/15930906 rows
#
# [10/110] Starting ▶ aisdk-2025-01-10.csv
# [10/110] Finished ✓ kept 6986470/16423838 rows
#
# [11/110] Starting ▶ aisdk-2025-01-11.csv
# [11/110] Finished ✓ kept 6782833/15617256 rows
#
# [12/110] Starting ▶ aisdk-2025-01-12.csv
# [12/110] Finished ✓ kept 6791042/16582129 rows
#
# [13/110] Starting ▶ aisdk-2025-01-13.csv
# [13/110] Finished ✓ kept 7256971/17364983 rows
#
# [14/110] Starting ▶ aisdk-2025-01-14.csv
# [14/110] Finished ✓ kept 6604840/16201164 rows
#
# [15/110] Starting ▶ aisdk-2025-01-15.csv
# [15/110] Finished ✓ kept 8854872/19914968 rows
#
# [16/110] Starting ▶ aisdk-2025-01-16.csv
# [16/110] Finished ✓ kept 14132010/26728908 rows
#
# [17/110] Starting ▶ aisdk-2025-01-17.csv
# [17/110] Finished ✓ kept 12793134/24829332 rows
#
# [18/110] Starting ▶ aisdk-2025-01-18.csv
# [18/110] Finished ✓ kept 11268793/22965355 rows
#
# [19/110] Starting ▶ aisdk-2025-01-19.csv
# [19/110] Finished ✓ kept 19284990/35746017 rows
#
# [20/110] Starting ▶ aisdk-2025-01-20.csv
# [20/110] Finished ✓ kept 11836034/24957006 rows
#
# [21/110] Starting ▶ aisdk-2025-01-21.csv
# [21/110] Finished ✓ kept 5957828/15359949 rows
#
# [22/110] Starting ▶ aisdk-2025-01-22.csv
# [22/110] Finished ✓ kept 6616710/16451188 rows
#
# [23/110] Starting ▶ aisdk-2025-01-23.csv
# [23/110] Finished ✓ kept 6315093/15657430 rows
#
# [24/110] Starting ▶ aisdk-2025-01-24.csv
# [24/110] Finished ✓ kept 6739877/15928075 rows
#
# [25/110] Starting ▶ aisdk-2025-01-25.csv
# [25/110] Finished ✓ kept 7927308/17422586 rows
#
# [26/110] Starting ▶ aisdk-2025-01-26.csv
# [26/110] Finished ✓ kept 6982643/16776432 rows
#
# [27/110] Starting ▶ aisdk-2025-01-27.csv
# [27/110] Finished ✓ kept 5865636/14868679 rows
#
# [28/110] Starting ▶ aisdk-2025-01-28.csv
# [28/110] Finished ✓ kept 6575988/16239528 rows
#
# [29/110] Starting ▶ aisdk-2025-01-29.csv
# [29/110] Finished ✓ kept 6672932/16522545 rows
#
# [30/110] Starting ▶ aisdk-2025-01-30.csv
# [30/110] Finished ✓ kept 6430082/15870700 rows
#
# [31/110] Starting ▶ aisdk-2025-01-31.csv
# [31/110] Finished ✓ kept 6613227/16077040 rows
#
# [32/110] Starting ▶ aisdk-2025-02-01.csv
# [32/110] Finished ✓ kept 7382429/17743547 rows
#
# [33/110] Starting ▶ aisdk-2025-02-02.csv
# [33/110] Finished ✓ kept 6723894/16692211 rows
#
# [34/110] Starting ▶ aisdk-2025-02-03.csv
# [34/110] Finished ✓ kept 7022268/17200486 rows
#
# [35/110] Starting ▶ aisdk-2025-02-04.csv
# [35/110] Finished ✓ kept 7314834/17579673 rows
#
# [36/110] Starting ▶ aisdk-2025-02-05.csv
# [36/110] Finished ✓ kept 6917942/16767763 rows
#
# [37/110] Starting ▶ aisdk-2025-02-06.csv
# [37/110] Finished ✓ kept 8111808/18996610 rows
#
# [38/110] Starting ▶ aisdk-2025-02-07.csv
# [38/110] Finished ✓ kept 7187555/16779540 rows
#
# [39/110] Starting ▶ aisdk-2025-02-08.csv
# [39/110] Finished ✓ kept 6694357/15575487 rows
#
# [40/110] Starting ▶ aisdk-2025-02-09.csv
# [40/110] Finished ✓ kept 6346324/15366010 rows
#
# [41/110] Starting ▶ aisdk-2025-02-10.csv
# [41/110] Finished ✓ kept 6045906/14942303 rows
#
# [42/110] Starting ▶ aisdk-2025-02-11.csv
# [42/110] Finished ✓ kept 6270956/15068239 rows
#
# [43/110] Starting ▶ aisdk-2025-02-12.csv
# [43/110] Finished ✓ kept 5985484/15014806 rows
#
# [44/110] Starting ▶ aisdk-2025-02-13.csv
# [44/110] Finished ✓ kept 6396355/15749668 rows
#
# [45/110] Starting ▶ aisdk-2025-02-14.csv
# [45/110] Finished ✓ kept 5805917/14378089 rows
#
# [46/110] Starting ▶ aisdk-2025-02-15.csv
# [46/110] Finished ✓ kept 5858199/14386666 rows
#
# [47/110] Starting ▶ aisdk-2025-02-16.csv
# [47/110] Finished ✓ kept 5802784/14212876 rows
#
# [48/110] Starting ▶ aisdk-2025-02-17.csv
# [48/110] Finished ✓ kept 5633128/14459124 rows
#
# [49/110] Starting ▶ aisdk-2025-02-18.csv
# [49/110] Finished ✓ kept 5939780/16172829 rows
#
# [50/110] Starting ▶ aisdk-2025-02-19.csv
# [50/110] Finished ✓ kept 6774460/17699007 rows
#
# [51/110] Starting ▶ aisdk-2025-02-20.csv
# [51/110] Finished ✓ kept 6219896/15514267 rows
#
# [52/110] Starting ▶ aisdk-2025-02-21.csv
# [52/110] Finished ✓ kept 6157593/15409057 rows
#
# [53/110] Starting ▶ aisdk-2025-02-22.csv
# [53/110] Finished ✓ kept 6274115/15951303 rows
#
# [54/110] Starting ▶ aisdk-2025-02-23.csv
# [54/110] Finished ✓ kept 7002425/17146722 rows
#
# [55/110] Starting ▶ aisdk-2025-02-24.csv
# [55/110] Finished ✓ kept 6716886/16906707 rows
#
# [56/110] Starting ▶ aisdk-2025-02-25.csv
# [56/110] Finished ✓ kept 6834969/17143288 rows
#
# [57/110] Starting ▶ aisdk-2025-02-26.csv
# [57/110] Finished ✓ kept 6752754/17350107 rows
#
# [58/110] Starting ▶ aisdk-2025-02-27.csv
# [58/110] Finished ✓ kept 6417756/17164902 rows
#
# [59/110] Starting ▶ aisdk-2025-02-28.csv
# [59/110] Finished ✓ kept 7581546/18301921 rows
#
# [60/110] Starting ▶ aisdk-2025-03-01.csv
# [60/110] Finished ✓ kept 8586206/18977895 rows
#
# [61/110] Starting ▶ aisdk-2025-03-02.csv
# [61/110] Finished ✓ kept 7503999/17141675 rows
#
# [62/110] Starting ▶ aisdk-2025-03-03.csv
# [62/110] Finished ✓ kept 6671507/15981311 rows
#
# [63/110] Starting ▶ aisdk-2025-03-04.csv
# [63/110] Finished ✓ kept 6759623/16151789 rows
#
# [64/110] Starting ▶ aisdk-2025-03-05.csv
# [64/110] Finished ✓ kept 9638136/20754498 rows
#
# [65/110] Starting ▶ aisdk-2025-03-06.csv
# [65/110] Finished ✓ kept 11573327/24168735 rows
#
# [66/110] Starting ▶ aisdk-2025-03-07.csv
# [66/110] Finished ✓ kept 9807893/22460205 rows
#
# [67/110] Starting ▶ aisdk-2025-03-08.csv
# [67/110] Finished ✓ kept 8125006/18857539 rows
#
# [68/110] Starting ▶ aisdk-2025-03-09.csv
# [68/110] Finished ✓ kept 10246577/22575869 rows
#
# [69/110] Starting ▶ aisdk-2025-03-10.csv
# [69/110] Finished ✓ kept 8590847/20344072 rows
#
# [70/110] Starting ▶ aisdk-2025-03-11.csv
# [70/110] Finished ✓ kept 7105028/17243148 rows
#
# [71/110] Starting ▶ aisdk-2025-03-12.csv
# [71/110] Finished ✓ kept 6575337/16955058 rows
#
# [72/110] Starting ▶ aisdk-2025-03-13.csv
# [72/110] Finished ✓ kept 7156237/17408601 rows
#
# [73/110] Starting ▶ aisdk-2025-03-14.csv
# [73/110] Finished ✓ kept 6864512/16750202 rows
#
# [74/110] Starting ▶ aisdk-2025-03-15.csv
# [74/110] Finished ✓ kept 7105253/17126588 rows
#
# [75/110] Starting ▶ aisdk-2025-03-16.csv
# [75/110] Finished ✓ kept 6640144/16374587 rows
#
# [76/110] Starting ▶ aisdk-2025-03-17.csv
# [76/110] Finished ✓ kept 6337012/16622068 rows
#
# [77/110] Starting ▶ aisdk-2025-03-18.csv
# [77/110] Finished ✓ kept 7606556/18440182 rows
#
# [78/110] Starting ▶ aisdk-2025-03-19.csv
# [78/110] Finished ✓ kept 10000166/22381011 rows
#
# [79/110] Starting ▶ aisdk-2025-03-20.csv
# [79/110] Finished ✓ kept 12273651/27432658 rows
#
# [80/110] Starting ▶ aisdk-2025-03-21.csv
# [80/110] Finished ✓ kept 11084909/24721580 rows
#
# [81/110] Starting ▶ aisdk-2025-03-22.csv
# [81/110] Finished ✓ kept 8712101/18912608 rows
#
# [82/110] Starting ▶ aisdk-2025-03-23.csv
# [82/110] Finished ✓ kept 7650315/17820245 rows
#
# [83/110] Starting ▶ aisdk-2025-03-24.csv
# [83/110] Finished ✓ kept 8023121/19087753 rows
#
# [84/110] Starting ▶ aisdk-2025-03-25.csv
# [84/110] Finished ✓ kept 7438553/17690637 rows
#
# [85/110] Starting ▶ aisdk-2025-03-26.csv
# [85/110] Finished ✓ kept 7275228/17834159 rows
#
# [86/110] Starting ▶ aisdk-2025-03-27.csv
# [86/110] Finished ✓ kept 6845375/17017113 rows
#
# [87/110] Starting ▶ aisdk-2025-03-28.csv
# [87/110] Finished ✓ kept 7457063/17741000 rows
#
# [88/110] Starting ▶ aisdk-2025-03-29.csv
# [88/110] Finished ✓ kept 7116549/17408575 rows
#
# [89/110] Starting ▶ aisdk-2025-03-30.csv
# [89/110] Finished ✓ kept 6505259/15845324 rows
#
# [90/110] Starting ▶ aisdk-2025-03-31.csv
# [90/110] Finished ✓ kept 8652965/20096978 rows
#
# [91/110] Starting ▶ aisdk-2025-04-01.csv
# [91/110] Finished ✓ kept 11561540/26463839 rows
#
# [92/110] Starting ▶ aisdk-2025-04-02.csv
# [92/110] Finished ✓ kept 8733014/21799256 rows
#
# [93/110] Starting ▶ aisdk-2025-04-03.csv
# [93/110] Finished ✓ kept 8760339/21290984 rows
#
# [94/110] Starting ▶ aisdk-2025-04-04.csv
# [94/110] Finished ✓ kept 9569285/22063330 rows
#
# [95/110] Starting ▶ aisdk-2025-04-05.csv
# [95/110] Finished ✓ kept 6693499/16482737 rows
#
# [96/110] Starting ▶ aisdk-2025-04-06.csv
# [96/110] Finished ✓ kept 7129025/17729597 rows
#
# [97/110] Starting ▶ aisdk-2025-04-07.csv
# [97/110] Finished ✓ kept 8557343/20695524 rows
#
# [98/110] Starting ▶ aisdk-2025-04-08.csv
# [98/110] Finished ✓ kept 8555851/20970901 rows
#
# [99/110] Starting ▶ aisdk-2025-04-09.csv
# [99/110] Finished ✓ kept 8378168/20481140 rows
#
# [100/110] Starting ▶ aisdk-2025-04-10.csv
# [100/110] Finished ✓ kept 8183018/19319294 rows
#
# [101/110] Starting ▶ aisdk-2025-04-11.csv
# [101/110] Finished ✓ kept 7542261/17633480 rows
#
# [102/110] Starting ▶ aisdk-2025-04-12.csv
# [102/110] Finished ✓ kept 8538662/19191901 rows
#
# [103/110] Starting ▶ aisdk-2025-04-13.csv
# [103/110] Finished ✓ kept 7065200/17587770 rows
#
# [104/110] Starting ▶ aisdk-2025-04-14.csv
# [104/110] Finished ✓ kept 6926399/17672010 rows
#
# [105/110] Starting ▶ aisdk-2025-04-15.csv
# [105/110] Finished ✓ kept 7772242/19104915 rows
#
# [106/110] Starting ▶ aisdk-2025-04-16.csv
# [106/110] Finished ✓ kept 7019981/17939295 rows
#
# [107/110] Starting ▶ aisdk-2025-04-17.csv
# [107/110] Finished ✓ kept 7699641/18720513 rows
#
# [108/110] Starting ▶ aisdk-2025-04-18.csv
# [108/110] Finished ✓ kept 10030678/21927331 rows
#
# [109/110] Starting ▶ aisdk-2025-04-19.csv
# [109/110] Finished ✓ kept 8273060/19065402 rows
#
# [110/110] Starting ▶ aisdk-2025-04-20.csv
# [110/110] Finished ✓ kept 7338969/17748660 rows
#
# All done!  Summary written to D:\Thesis Work MLS\Denmark AIS data\processed_files\summary.csv
